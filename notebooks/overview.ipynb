# %% [markdown]
# # Overview of HydroGym features

# %%
import firedrake as fd
import firedrake_adjoint as fda
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from ufl import dx, inner

import hydrogym.firedrake as hgym

mpl.rc("text", usetex=False)
mpl.rc("font", family="serif")
mpl.rc("xtick", labelsize=14)
mpl.rc("ytick", labelsize=14)
mpl.rc("axes", labelsize=20)
mpl.rc("axes", titlesize=20)
mpl.rc("figure", figsize=(6, 4))
# %config InlineBackend.figure_format = 'retina'

precomputed_data = "../examples/demo"
# Out:
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# firedrake:WARNING OMP_NUM_THREADS is not set or is set to a value greater than 1, we suggest setting OMP_NUM_THREADS=1 to improve performance
# /home/jay/miniconda3/envs/hydrogym/lib/python3.12/site-packages/firedrake_adjoint/__init__.py:9: FutureWarning: The firedrake_adjoint module is deprecated.
#
# Instead, use the firedrake.adjoint module and explicitly start taping
# by calling continue_annotation().
#   warnings.warn("""The firedrake_adjoint module is deprecated.

# %% [markdown]
# # High-level interface
#
# The highest-level interface is an implementation of the OpenAI gym `Env` called `FlowEnv`, where you have to do almost nothing to run the simulation.  We can optionally load from a previous checkpoint, which we'll do here to save time.

# %%
env_config = {
    "flow": hgym.RotaryCylinder,
    "flow_config": {
        "Re" :100,
        "restart": f"{precomputed_data}/checkpoint.h5",
        "mesh":'medium',
        "velocity_order":1
    },
    "solver_config":{
        "dt":0.01,
    },
    "solver": hgym.SemiImplicitBDF,
}
env = hgym.FlowEnv(env_config)

# %% [markdown]
# Firedrake has a [full set of plotting tools](https://www.firedrakeproject.org/_modules/firedrake/plot.html) built on matplotlib, but as an easy way to see what's going on, the `FlowEnv` can also render the flow and plot vorticity.
#
# For a much more powerful set of visualization tools, the fields can also be written out to Paraview.  We'll come back to that later.

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 3))
env.render(axes=ax)
plt.show()

# %% [markdown]
# Keyword arguments are passed on to firedrake and then matplotlib, so the behavior is similar to what you'd expect for `matplotlib.contourf`

# %%
fig, ax = plt.subplots(1, 1, figsize=(7.5, 3))
env.render(axes=ax, cmap=sns.color_palette("icefire", as_cmap=True))
ax.set_xlim([-2, 9])
ax.set_ylim([-2, 2])
plt.show()

# %% [markdown]
# We can easily step the simulation forward in time by calling the `step` method.  This takes as an optional input the control "action" (more on this in a minute).  If not supplied the flow will just evolve naturally.
#
# `step` returns a tuple of `(obs, reward, done, info)`.  For the cylinder the observations are the lift and drag coefficients.  Since the objective is drag minimization, `reward` is negative drag (maximizing negative drag = minimizing drag).  As of now `done` and `info` are not implemented.
#
# The vortex shedding period is about 5.6, so let's run it for about half of that and compare to the previous state.

# %%
# %%time
# Runtime: ~2m
Tf = 2.8
num_steps = int(Tf // env.solver.dt)
for i in range(num_steps):
    (CL, CD), _, _, _ = env.step()  # obs, reward, done, info
    print(f"Step: {i+1}/{num_steps},\tLift: {CL:0.3f},\tDrag: {CD:0.3f}")
# Out:
# Step: 1/279,	Lift: -0.155,	Drag: 1.510
# Step: 2/279,	Lift: -0.158,	Drag: 1.484
# Step: 3/279,	Lift: -0.163,	Drag: 1.482
# Step: 4/279,	Lift: -0.167,	Drag: 1.481
# Step: 5/279,	Lift: -0.170,	Drag: 1.480
# Step: 6/279,	Lift: -0.174,	Drag: 1.479
# Step: 7/279,	Lift: -0.177,	Drag: 1.478
# Step: 8/279,	Lift: -0.181,	Drag: 1.477
# Step: 9/279,	Lift: -0.184,	Drag: 1.476
# Step: 10/279,	Lift: -0.188,	Drag: 1.476
# Step: 11/279,	Lift: -0.191,	Drag: 1.475
# Step: 12/279,	Lift: -0.195,	Drag: 1.475
# Step: 13/279,	Lift: -0.198,	Drag: 1.474
# Step: 14/279,	Lift: -0.201,	Drag: 1.474
# Step: 15/279,	Lift: -0.205,	Drag: 1.473
# Step: 16/279,	Lift: -0.208,	Drag: 1.473
# Step: 17/279,	Lift: -0.211,	Drag: 1.473
# Step: 18/279,	Lift: -0.215,	Drag: 1.472
# Step: 19/279,	Lift: -0.218,	Drag: 1.472
# Step: 20/279,	Lift: -0.221,	Drag: 1.472
# Step: 21/279,	Lift: -0.224,	Drag: 1.472
# Step: 22/279,	Lift: -0.228,	Drag: 1.472
# Step: 23/279,	Lift: -0.231,	Drag: 1.471
# Step: 24/279,	Lift: -0.234,	Drag: 1.471
# Step: 25/279,	Lift: -0.237,	Drag: 1.471
# Step: 26/279,	Lift: -0.240,	Drag: 1.471
# Step: 27/279,	Lift: -0.243,	Drag: 1.471
# Step: 28/279,	Lift: -0.246,	Drag: 1.471
# Step: 29/279,	Lift: -0.249,	Drag: 1.471
# Step: 30/279,	Lift: -0.252,	Drag: 1.471
# Step: 31/279,	Lift: -0.255,	Drag: 1.471
# Step: 32/279,	Lift: -0.258,	Drag: 1.471
# Step: 33/279,	Lift: -0.260,	Drag: 1.471
# Step: 34/279,	Lift: -0.263,	Drag: 1.471
# Step: 35/279,	Lift: -0.266,	Drag: 1.471
# Step: 36/279,	Lift: -0.269,	Drag: 1.471
# Step: 37/279,	Lift: -0.271,	Drag: 1.471
# Step: 38/279,	Lift: -0.274,	Drag: 1.471
# Step: 39/279,	Lift: -0.277,	Drag: 1.471
# Step: 40/279,	Lift: -0.279,	Drag: 1.471
# Step: 41/279,	Lift: -0.282,	Drag: 1.471
# Step: 42/279,	Lift: -0.284,	Drag: 1.471
# Step: 43/279,	Lift: -0.287,	Drag: 1.471
# Step: 44/279,	Lift: -0.289,	Drag: 1.471
# Step: 45/279,	Lift: -0.291,	Drag: 1.471
# Step: 46/279,	Lift: -0.294,	Drag: 1.471
# Step: 47/279,	Lift: -0.296,	Drag: 1.471
# Step: 48/279,	Lift: -0.298,	Drag: 1.471
# Step: 49/279,	Lift: -0.301,	Drag: 1.471
# Step: 50/279,	Lift: -0.303,	Drag: 1.472
# Step: 51/279,	Lift: -0.305,	Drag: 1.472
# Step: 52/279,	Lift: -0.307,	Drag: 1.472
# Step: 53/279,	Lift: -0.309,	Drag: 1.472
# Step: 54/279,	Lift: -0.311,	Drag: 1.472
# Step: 55/279,	Lift: -0.313,	Drag: 1.472
# Step: 56/279,	Lift: -0.315,	Drag: 1.472
# Step: 57/279,	Lift: -0.317,	Drag: 1.472
# Step: 58/279,	Lift: -0.319,	Drag: 1.473
# Step: 59/279,	Lift: -0.321,	Drag: 1.473
# Step: 60/279,	Lift: -0.323,	Drag: 1.473
# Step: 61/279,	Lift: -0.324,	Drag: 1.473
# Step: 62/279,	Lift: -0.326,	Drag: 1.473
# Step: 63/279,	Lift: -0.328,	Drag: 1.473
# Step: 64/279,	Lift: -0.329,	Drag: 1.474
# Step: 65/279,	Lift: -0.331,	Drag: 1.474
# Step: 66/279,	Lift: -0.333,	Drag: 1.474
# Step: 67/279,	Lift: -0.334,	Drag: 1.474
# Step: 68/279,	Lift: -0.335,	Drag: 1.474
# Step: 69/279,	Lift: -0.337,	Drag: 1.474
# Step: 70/279,	Lift: -0.338,	Drag: 1.475
# Step: 71/279,	Lift: -0.340,	Drag: 1.475
# Step: 72/279,	Lift: -0.341,	Drag: 1.475
# Step: 73/279,	Lift: -0.342,	Drag: 1.475
# Step: 74/279,	Lift: -0.343,	Drag: 1.475
# Step: 75/279,	Lift: -0.344,	Drag: 1.476
# Step: 76/279,	Lift: -0.346,	Drag: 1.476
# Step: 77/279,	Lift: -0.347,	Drag: 1.476
# Step: 78/279,	Lift: -0.348,	Drag: 1.476
# Step: 79/279,	Lift: -0.349,	Drag: 1.476
# Step: 80/279,	Lift: -0.350,	Drag: 1.477
# Step: 81/279,	Lift: -0.350,	Drag: 1.477
# Step: 82/279,	Lift: -0.351,	Drag: 1.477
# Step: 83/279,	Lift: -0.352,	Drag: 1.477
# Step: 84/279,	Lift: -0.353,	Drag: 1.477
# Step: 85/279,	Lift: -0.354,	Drag: 1.477
# Step: 86/279,	Lift: -0.354,	Drag: 1.478
# Step: 87/279,	Lift: -0.355,	Drag: 1.478
# Step: 88/279,	Lift: -0.355,	Drag: 1.478
# Step: 89/279,	Lift: -0.356,	Drag: 1.478
# Step: 90/279,	Lift: -0.356,	Drag: 1.478
# Step: 91/279,	Lift: -0.357,	Drag: 1.479
# Step: 92/279,	Lift: -0.357,	Drag: 1.479
# Step: 93/279,	Lift: -0.358,	Drag: 1.479
# Step: 94/279,	Lift: -0.358,	Drag: 1.479
# Step: 95/279,	Lift: -0.358,	Drag: 1.479
# Step: 96/279,	Lift: -0.358,	Drag: 1.479
# Step: 97/279,	Lift: -0.358,	Drag: 1.480
# Step: 98/279,	Lift: -0.359,	Drag: 1.480
# Step: 99/279,	Lift: -0.359,	Drag: 1.480
# Step: 100/279,	Lift: -0.359,	Drag: 1.480
# Step: 101/279,	Lift: -0.359,	Drag: 1.480
# Step: 102/279,	Lift: -0.359,	Drag: 1.480
# Step: 103/279,	Lift: -0.358,	Drag: 1.481
# Step: 104/279,	Lift: -0.358,	Drag: 1.481
# Step: 105/279,	Lift: -0.358,	Drag: 1.481
# Step: 106/279,	Lift: -0.358,	Drag: 1.481
# Step: 107/279,	Lift: -0.358,	Drag: 1.481
# Step: 108/279,	Lift: -0.357,	Drag: 1.481
# Step: 109/279,	Lift: -0.357,	Drag: 1.481
# Step: 110/279,	Lift: -0.356,	Drag: 1.481
# Step: 111/279,	Lift: -0.356,	Drag: 1.482
# Step: 112/279,	Lift: -0.355,	Drag: 1.482
# Step: 113/279,	Lift: -0.355,	Drag: 1.482
# Step: 114/279,	Lift: -0.354,	Drag: 1.482
# Step: 115/279,	Lift: -0.354,	Drag: 1.482
# Step: 116/279,	Lift: -0.353,	Drag: 1.482
# Step: 117/279,	Lift: -0.352,	Drag: 1.482
# Step: 118/279,	Lift: -0.351,	Drag: 1.482
# Step: 119/279,	Lift: -0.351,	Drag: 1.482
# Step: 120/279,	Lift: -0.350,	Drag: 1.482
# Step: 121/279,	Lift: -0.349,	Drag: 1.483
# Step: 122/279,	Lift: -0.348,	Drag: 1.483
# Step: 123/279,	Lift: -0.347,	Drag: 1.483
# Step: 124/279,	Lift: -0.346,	Drag: 1.483
# Step: 125/279,	Lift: -0.345,	Drag: 1.483
# Step: 126/279,	Lift: -0.343,	Drag: 1.483
# Step: 127/279,	Lift: -0.342,	Drag: 1.483
# Step: 128/279,	Lift: -0.341,	Drag: 1.483
# Step: 129/279,	Lift: -0.340,	Drag: 1.483
# Step: 130/279,	Lift: -0.338,	Drag: 1.483
# Step: 131/279,	Lift: -0.337,	Drag: 1.483
# Step: 132/279,	Lift: -0.336,	Drag: 1.483
# Step: 133/279,	Lift: -0.334,	Drag: 1.483
# Step: 134/279,	Lift: -0.333,	Drag: 1.483
# Step: 135/279,	Lift: -0.331,	Drag: 1.483
# Step: 136/279,	Lift: -0.330,	Drag: 1.483
# Step: 137/279,	Lift: -0.328,	Drag: 1.483
# Step: 138/279,	Lift: -0.326,	Drag: 1.483
# Step: 139/279,	Lift: -0.325,	Drag: 1.483
# Step: 140/279,	Lift: -0.323,	Drag: 1.483
# Step: 141/279,	Lift: -0.321,	Drag: 1.483
# Step: 142/279,	Lift: -0.319,	Drag: 1.483
# Step: 143/279,	Lift: -0.318,	Drag: 1.483
# Step: 144/279,	Lift: -0.316,	Drag: 1.483
# Step: 145/279,	Lift: -0.314,	Drag: 1.483
# Step: 146/279,	Lift: -0.312,	Drag: 1.483
# Step: 147/279,	Lift: -0.310,	Drag: 1.483
# Step: 148/279,	Lift: -0.308,	Drag: 1.483
# Step: 149/279,	Lift: -0.306,	Drag: 1.483
# Step: 150/279,	Lift: -0.304,	Drag: 1.483
# Step: 151/279,	Lift: -0.301,	Drag: 1.482
# Step: 152/279,	Lift: -0.299,	Drag: 1.482
# Step: 153/279,	Lift: -0.297,	Drag: 1.482
# Step: 154/279,	Lift: -0.295,	Drag: 1.482
# Step: 155/279,	Lift: -0.292,	Drag: 1.482
# Step: 156/279,	Lift: -0.290,	Drag: 1.482
# Step: 157/279,	Lift: -0.288,	Drag: 1.482
# Step: 158/279,	Lift: -0.285,	Drag: 1.482
# Step: 159/279,	Lift: -0.283,	Drag: 1.482
# Step: 160/279,	Lift: -0.280,	Drag: 1.482
# Step: 161/279,	Lift: -0.278,	Drag: 1.481
# Step: 162/279,	Lift: -0.275,	Drag: 1.481
# Step: 163/279,	Lift: -0.273,	Drag: 1.481
# Step: 164/279,	Lift: -0.270,	Drag: 1.481
# Step: 165/279,	Lift: -0.267,	Drag: 1.481
# Step: 166/279,	Lift: -0.265,	Drag: 1.481
# Step: 167/279,	Lift: -0.262,	Drag: 1.481
# Step: 168/279,	Lift: -0.259,	Drag: 1.480
# Step: 169/279,	Lift: -0.256,	Drag: 1.480
# Step: 170/279,	Lift: -0.254,	Drag: 1.480
# Step: 171/279,	Lift: -0.251,	Drag: 1.480
# Step: 172/279,	Lift: -0.248,	Drag: 1.480
# Step: 173/279,	Lift: -0.245,	Drag: 1.480
# Step: 174/279,	Lift: -0.242,	Drag: 1.479
# Step: 175/279,	Lift: -0.239,	Drag: 1.479
# Step: 176/279,	Lift: -0.236,	Drag: 1.479
# Step: 177/279,	Lift: -0.233,	Drag: 1.479
# Step: 178/279,	Lift: -0.230,	Drag: 1.479
# Step: 179/279,	Lift: -0.227,	Drag: 1.478
# Step: 180/279,	Lift: -0.224,	Drag: 1.478
# Step: 181/279,	Lift: -0.220,	Drag: 1.478
# Step: 182/279,	Lift: -0.217,	Drag: 1.478
# Step: 183/279,	Lift: -0.214,	Drag: 1.478
# Step: 184/279,	Lift: -0.211,	Drag: 1.477
# Step: 185/279,	Lift: -0.208,	Drag: 1.477
# Step: 186/279,	Lift: -0.204,	Drag: 1.477
# Step: 187/279,	Lift: -0.201,	Drag: 1.477
# Step: 188/279,	Lift: -0.198,	Drag: 1.477
# Step: 189/279,	Lift: -0.194,	Drag: 1.476
# Step: 190/279,	Lift: -0.191,	Drag: 1.476
# Step: 191/279,	Lift: -0.187,	Drag: 1.476
# Step: 192/279,	Lift: -0.184,	Drag: 1.476
# Step: 193/279,	Lift: -0.181,	Drag: 1.476
# Step: 194/279,	Lift: -0.177,	Drag: 1.475
# Step: 195/279,	Lift: -0.174,	Drag: 1.475
# Step: 196/279,	Lift: -0.170,	Drag: 1.475
# Step: 197/279,	Lift: -0.167,	Drag: 1.475
# Step: 198/279,	Lift: -0.163,	Drag: 1.474
# Step: 199/279,	Lift: -0.159,	Drag: 1.474
# Step: 200/279,	Lift: -0.156,	Drag: 1.474
# Step: 201/279,	Lift: -0.152,	Drag: 1.474
# Step: 202/279,	Lift: -0.149,	Drag: 1.473
# Step: 203/279,	Lift: -0.145,	Drag: 1.473
# Step: 204/279,	Lift: -0.141,	Drag: 1.473
# Step: 205/279,	Lift: -0.137,	Drag: 1.473
# Step: 206/279,	Lift: -0.134,	Drag: 1.472
# Step: 207/279,	Lift: -0.130,	Drag: 1.472
# Step: 208/279,	Lift: -0.126,	Drag: 1.472
# Step: 209/279,	Lift: -0.123,	Drag: 1.472
# Step: 210/279,	Lift: -0.119,	Drag: 1.472
# Step: 211/279,	Lift: -0.115,	Drag: 1.471
# Step: 212/279,	Lift: -0.111,	Drag: 1.471
# Step: 213/279,	Lift: -0.107,	Drag: 1.471
# Step: 214/279,	Lift: -0.103,	Drag: 1.471
# Step: 215/279,	Lift: -0.100,	Drag: 1.470
# Step: 216/279,	Lift: -0.096,	Drag: 1.470
# Step: 217/279,	Lift: -0.092,	Drag: 1.470
# Step: 218/279,	Lift: -0.088,	Drag: 1.470
# Step: 219/279,	Lift: -0.084,	Drag: 1.469
# Step: 220/279,	Lift: -0.080,	Drag: 1.469
# Step: 221/279,	Lift: -0.076,	Drag: 1.469
# Step: 222/279,	Lift: -0.072,	Drag: 1.469
# Step: 223/279,	Lift: -0.068,	Drag: 1.469
# Step: 224/279,	Lift: -0.064,	Drag: 1.468
# Step: 225/279,	Lift: -0.060,	Drag: 1.468
# Step: 226/279,	Lift: -0.056,	Drag: 1.468
# Step: 227/279,	Lift: -0.052,	Drag: 1.468
# Step: 228/279,	Lift: -0.048,	Drag: 1.468
# Step: 229/279,	Lift: -0.044,	Drag: 1.467
# Step: 230/279,	Lift: -0.040,	Drag: 1.467
# Step: 231/279,	Lift: -0.036,	Drag: 1.467
# Step: 232/279,	Lift: -0.032,	Drag: 1.467
# Step: 233/279,	Lift: -0.028,	Drag: 1.467
# Step: 234/279,	Lift: -0.024,	Drag: 1.466
# Step: 235/279,	Lift: -0.020,	Drag: 1.466
# Step: 236/279,	Lift: -0.016,	Drag: 1.466
# Step: 237/279,	Lift: -0.012,	Drag: 1.466
# Step: 238/279,	Lift: -0.008,	Drag: 1.466
# Step: 239/279,	Lift: -0.004,	Drag: 1.465
# Step: 240/279,	Lift: -0.000,	Drag: 1.465
# Step: 241/279,	Lift: 0.004,	Drag: 1.465
# Step: 242/279,	Lift: 0.008,	Drag: 1.465
# Step: 243/279,	Lift: 0.012,	Drag: 1.465
# Step: 244/279,	Lift: 0.016,	Drag: 1.465
# Step: 245/279,	Lift: 0.020,	Drag: 1.465
# Step: 246/279,	Lift: 0.024,	Drag: 1.464
# Step: 247/279,	Lift: 0.028,	Drag: 1.464
# Step: 248/279,	Lift: 0.032,	Drag: 1.464
# Step: 249/279,	Lift: 0.036,	Drag: 1.464
# Step: 250/279,	Lift: 0.040,	Drag: 1.464
# Step: 251/279,	Lift: 0.044,	Drag: 1.464
# Step: 252/279,	Lift: 0.048,	Drag: 1.464
# Step: 253/279,	Lift: 0.052,	Drag: 1.464
# Step: 254/279,	Lift: 0.056,	Drag: 1.463
# Step: 255/279,	Lift: 0.060,	Drag: 1.463
# Step: 256/279,	Lift: 0.064,	Drag: 1.463
# Step: 257/279,	Lift: 0.068,	Drag: 1.463
# Step: 258/279,	Lift: 0.072,	Drag: 1.463
# Step: 259/279,	Lift: 0.076,	Drag: 1.463
# Step: 260/279,	Lift: 0.080,	Drag: 1.463
# Step: 261/279,	Lift: 0.084,	Drag: 1.463
# Step: 262/279,	Lift: 0.088,	Drag: 1.463
# Step: 263/279,	Lift: 0.092,	Drag: 1.463
# Step: 264/279,	Lift: 0.096,	Drag: 1.463
# Step: 265/279,	Lift: 0.100,	Drag: 1.463
# Step: 266/279,	Lift: 0.103,	Drag: 1.463
# Step: 267/279,	Lift: 0.107,	Drag: 1.463
# Step: 268/279,	Lift: 0.111,	Drag: 1.463
# Step: 269/279,	Lift: 0.115,	Drag: 1.462
# Step: 270/279,	Lift: 0.119,	Drag: 1.462
# Step: 271/279,	Lift: 0.123,	Drag: 1.462
# Step: 272/279,	Lift: 0.126,	Drag: 1.462
# Step: 273/279,	Lift: 0.130,	Drag: 1.462
# Step: 274/279,	Lift: 0.134,	Drag: 1.462
# Step: 275/279,	Lift: 0.138,	Drag: 1.462
# Step: 276/279,	Lift: 0.142,	Drag: 1.462
# Step: 277/279,	Lift: 0.145,	Drag: 1.463
# Step: 278/279,	Lift: 0.149,	Drag: 1.463
# Step: 279/279,	Lift: 0.153,	Drag: 1.463
# CPU times: user 2min 39s, sys: 9min 38s, total: 12min 18s
# Wall time: 2min 47s

# %% [markdown]
# The vortex shedding has advanced by about half a period compared to the initial state.

# %%
fig, ax = plt.subplots(1, 1, figsize=(7.5, 3))
env.render(axes=ax, cmap=sns.color_palette("icefire", as_cmap=True))
ax.set_xlim([-2, 9])
ax.set_ylim([-2, 2])
plt.show()

# %% [markdown]
# As usual with `Env` objects, we can `reset` to the initial state if we want.

# %%
CL, CD = env.reset()
fig, ax = plt.subplots(1, 1, figsize=(7.5, 3))
env.render(axes=ax, cmap=sns.color_palette("icefire", as_cmap=True))
ax.set_xlim([-2, 9])
ax.set_ylim([-2, 2])
# Out:
# (-2.0, 2.0)

# %% [markdown]
# ### Adding control
#
# The cylinder case has a single control, which is the rotation rate of the cylinder.  Often the goal will be to derive some open-loop or closed-loop control strategy that can minimize the drag, but to see how it works we can just define a constant `action` and re-run the simulation.  Note how different the lift/drag numbers are from the "natural" dynamics and the deflection of the vortex shedding compared to the previous simulation

# %%
# Runtime: ~2m
Tf = 2.8
num_steps = int(Tf // env.solver.dt)
env.reset()
action = -0.5  # Rotation rate in rad/s
for i in range(num_steps):
    (CL, CD), _, _, _ = env.step(action)  # obs, reward, done, info
    print(f"Step: {i+1}/{num_steps},\tLift: {CL:0.3f},\tDrag: {CD:0.3f}")
# Out:
# Step: 1/279,	Lift: -0.180,	Drag: 1.511
# Step: 2/279,	Lift: -0.176,	Drag: 1.482
# Step: 3/279,	Lift: -0.176,	Drag: 1.479
# Step: 4/279,	Lift: -0.176,	Drag: 1.477
# Step: 5/279,	Lift: -0.176,	Drag: 1.475
# Step: 6/279,	Lift: -0.175,	Drag: 1.474
# Step: 7/279,	Lift: -0.174,	Drag: 1.473
# Step: 8/279,	Lift: -0.174,	Drag: 1.472
# Step: 9/279,	Lift: -0.173,	Drag: 1.472
# Step: 10/279,	Lift: -0.173,	Drag: 1.471
# Step: 11/279,	Lift: -0.173,	Drag: 1.471
# Step: 12/279,	Lift: -0.173,	Drag: 1.471
# Step: 13/279,	Lift: -0.173,	Drag: 1.471
# Step: 14/279,	Lift: -0.174,	Drag: 1.471
# Step: 15/279,	Lift: -0.174,	Drag: 1.470
# Step: 16/279,	Lift: -0.175,	Drag: 1.470
# Step: 17/279,	Lift: -0.176,	Drag: 1.470
# Step: 18/279,	Lift: -0.177,	Drag: 1.470
# Step: 19/279,	Lift: -0.178,	Drag: 1.470
# Step: 20/279,	Lift: -0.179,	Drag: 1.471
# Step: 21/279,	Lift: -0.180,	Drag: 1.471
# Step: 22/279,	Lift: -0.181,	Drag: 1.471
# Step: 23/279,	Lift: -0.182,	Drag: 1.471
# Step: 24/279,	Lift: -0.183,	Drag: 1.471
# Step: 25/279,	Lift: -0.184,	Drag: 1.471
# Step: 26/279,	Lift: -0.185,	Drag: 1.471
# Step: 27/279,	Lift: -0.187,	Drag: 1.471
# Step: 28/279,	Lift: -0.188,	Drag: 1.471
# Step: 29/279,	Lift: -0.189,	Drag: 1.472
# Step: 30/279,	Lift: -0.190,	Drag: 1.472
# Step: 31/279,	Lift: -0.191,	Drag: 1.472
# Step: 32/279,	Lift: -0.193,	Drag: 1.472
# Step: 33/279,	Lift: -0.194,	Drag: 1.472
# Step: 34/279,	Lift: -0.195,	Drag: 1.473
# Step: 35/279,	Lift: -0.196,	Drag: 1.473
# Step: 36/279,	Lift: -0.197,	Drag: 1.473
# Step: 37/279,	Lift: -0.198,	Drag: 1.473
# Step: 38/279,	Lift: -0.199,	Drag: 1.474
# Step: 39/279,	Lift: -0.200,	Drag: 1.474
# Step: 40/279,	Lift: -0.201,	Drag: 1.474
# Step: 41/279,	Lift: -0.202,	Drag: 1.475
# Step: 42/279,	Lift: -0.203,	Drag: 1.475
# Step: 43/279,	Lift: -0.204,	Drag: 1.475
# Step: 44/279,	Lift: -0.204,	Drag: 1.476
# Step: 45/279,	Lift: -0.205,	Drag: 1.476
# Step: 46/279,	Lift: -0.206,	Drag: 1.476
# Step: 47/279,	Lift: -0.206,	Drag: 1.477
# Step: 48/279,	Lift: -0.207,	Drag: 1.477
# Step: 49/279,	Lift: -0.207,	Drag: 1.478
# Step: 50/279,	Lift: -0.208,	Drag: 1.478
# Step: 51/279,	Lift: -0.208,	Drag: 1.478
# Step: 52/279,	Lift: -0.209,	Drag: 1.479
# Step: 53/279,	Lift: -0.209,	Drag: 1.479
# Step: 54/279,	Lift: -0.209,	Drag: 1.480
# Step: 55/279,	Lift: -0.210,	Drag: 1.480
# Step: 56/279,	Lift: -0.210,	Drag: 1.481
# Step: 57/279,	Lift: -0.210,	Drag: 1.481
# Step: 58/279,	Lift: -0.210,	Drag: 1.482
# Step: 59/279,	Lift: -0.210,	Drag: 1.482
# Step: 60/279,	Lift: -0.210,	Drag: 1.483
# Step: 61/279,	Lift: -0.210,	Drag: 1.483
# Step: 62/279,	Lift: -0.210,	Drag: 1.484
# Step: 63/279,	Lift: -0.209,	Drag: 1.484
# Step: 64/279,	Lift: -0.209,	Drag: 1.485
# Step: 65/279,	Lift: -0.209,	Drag: 1.485
# Step: 66/279,	Lift: -0.208,	Drag: 1.486
# Step: 67/279,	Lift: -0.208,	Drag: 1.487
# Step: 68/279,	Lift: -0.207,	Drag: 1.487
# Step: 69/279,	Lift: -0.207,	Drag: 1.488
# Step: 70/279,	Lift: -0.206,	Drag: 1.488
# Step: 71/279,	Lift: -0.205,	Drag: 1.489
# Step: 72/279,	Lift: -0.205,	Drag: 1.490
# Step: 73/279,	Lift: -0.204,	Drag: 1.490
# Step: 74/279,	Lift: -0.203,	Drag: 1.491
# Step: 75/279,	Lift: -0.202,	Drag: 1.491
# Step: 76/279,	Lift: -0.201,	Drag: 1.492
# Step: 77/279,	Lift: -0.200,	Drag: 1.493
# Step: 78/279,	Lift: -0.199,	Drag: 1.493
# Step: 79/279,	Lift: -0.197,	Drag: 1.494
# Step: 80/279,	Lift: -0.196,	Drag: 1.495
# Step: 81/279,	Lift: -0.195,	Drag: 1.495
# Step: 82/279,	Lift: -0.193,	Drag: 1.496
# Step: 83/279,	Lift: -0.192,	Drag: 1.497
# Step: 84/279,	Lift: -0.190,	Drag: 1.497
# Step: 85/279,	Lift: -0.189,	Drag: 1.498
# Step: 86/279,	Lift: -0.187,	Drag: 1.499
# Step: 87/279,	Lift: -0.185,	Drag: 1.499
# Step: 88/279,	Lift: -0.184,	Drag: 1.500
# Step: 89/279,	Lift: -0.182,	Drag: 1.501
# Step: 90/279,	Lift: -0.180,	Drag: 1.501
# Step: 91/279,	Lift: -0.178,	Drag: 1.502
# Step: 92/279,	Lift: -0.176,	Drag: 1.503
# Step: 93/279,	Lift: -0.174,	Drag: 1.503
# Step: 94/279,	Lift: -0.172,	Drag: 1.504
# Step: 95/279,	Lift: -0.169,	Drag: 1.505
# Step: 96/279,	Lift: -0.167,	Drag: 1.505
# Step: 97/279,	Lift: -0.165,	Drag: 1.506
# Step: 98/279,	Lift: -0.162,	Drag: 1.507
# Step: 99/279,	Lift: -0.160,	Drag: 1.507
# Step: 100/279,	Lift: -0.157,	Drag: 1.508
# Step: 101/279,	Lift: -0.155,	Drag: 1.509
# Step: 102/279,	Lift: -0.152,	Drag: 1.509
# Step: 103/279,	Lift: -0.149,	Drag: 1.510
# Step: 104/279,	Lift: -0.147,	Drag: 1.511
# Step: 105/279,	Lift: -0.144,	Drag: 1.511
# Step: 106/279,	Lift: -0.141,	Drag: 1.512
# Step: 107/279,	Lift: -0.138,	Drag: 1.513
# Step: 108/279,	Lift: -0.135,	Drag: 1.513
# Step: 109/279,	Lift: -0.132,	Drag: 1.514
# Step: 110/279,	Lift: -0.129,	Drag: 1.515
# Step: 111/279,	Lift: -0.125,	Drag: 1.515
# Step: 112/279,	Lift: -0.122,	Drag: 1.516
# Step: 113/279,	Lift: -0.119,	Drag: 1.516
# Step: 114/279,	Lift: -0.116,	Drag: 1.517
# Step: 115/279,	Lift: -0.112,	Drag: 1.518
# Step: 116/279,	Lift: -0.109,	Drag: 1.518
# Step: 117/279,	Lift: -0.105,	Drag: 1.519
# Step: 118/279,	Lift: -0.102,	Drag: 1.519
# Step: 119/279,	Lift: -0.098,	Drag: 1.520
# Step: 120/279,	Lift: -0.094,	Drag: 1.521
# Step: 121/279,	Lift: -0.091,	Drag: 1.521
# Step: 122/279,	Lift: -0.087,	Drag: 1.522
# Step: 123/279,	Lift: -0.083,	Drag: 1.522
# Step: 124/279,	Lift: -0.079,	Drag: 1.523
# Step: 125/279,	Lift: -0.075,	Drag: 1.523
# Step: 126/279,	Lift: -0.071,	Drag: 1.524
# Step: 127/279,	Lift: -0.067,	Drag: 1.525
# Step: 128/279,	Lift: -0.063,	Drag: 1.525
# Step: 129/279,	Lift: -0.059,	Drag: 1.526
# Step: 130/279,	Lift: -0.055,	Drag: 1.526
# Step: 131/279,	Lift: -0.050,	Drag: 1.527
# Step: 132/279,	Lift: -0.046,	Drag: 1.527
# Step: 133/279,	Lift: -0.042,	Drag: 1.528
# Step: 134/279,	Lift: -0.037,	Drag: 1.528
# Step: 135/279,	Lift: -0.033,	Drag: 1.529
# Step: 136/279,	Lift: -0.028,	Drag: 1.529
# Step: 137/279,	Lift: -0.024,	Drag: 1.530
# Step: 138/279,	Lift: -0.019,	Drag: 1.530
# Step: 139/279,	Lift: -0.015,	Drag: 1.530
# Step: 140/279,	Lift: -0.010,	Drag: 1.531
# Step: 141/279,	Lift: -0.005,	Drag: 1.531
# Step: 142/279,	Lift: -0.000,	Drag: 1.532
# Step: 143/279,	Lift: 0.004,	Drag: 1.532
# Step: 144/279,	Lift: 0.009,	Drag: 1.532
# Step: 145/279,	Lift: 0.014,	Drag: 1.533
# Step: 146/279,	Lift: 0.019,	Drag: 1.533
# Step: 147/279,	Lift: 0.024,	Drag: 1.534
# Step: 148/279,	Lift: 0.029,	Drag: 1.534
# Step: 149/279,	Lift: 0.034,	Drag: 1.534
# Step: 150/279,	Lift: 0.039,	Drag: 1.535
# Step: 151/279,	Lift: 0.045,	Drag: 1.535
# Step: 152/279,	Lift: 0.050,	Drag: 1.535
# Step: 153/279,	Lift: 0.055,	Drag: 1.535
# Step: 154/279,	Lift: 0.060,	Drag: 1.536
# Step: 155/279,	Lift: 0.066,	Drag: 1.536
# Step: 156/279,	Lift: 0.071,	Drag: 1.536
# Step: 157/279,	Lift: 0.076,	Drag: 1.536
# Step: 158/279,	Lift: 0.082,	Drag: 1.537
# Step: 159/279,	Lift: 0.087,	Drag: 1.537
# Step: 160/279,	Lift: 0.093,	Drag: 1.537
# Step: 161/279,	Lift: 0.098,	Drag: 1.537
# Step: 162/279,	Lift: 0.104,	Drag: 1.538
# Step: 163/279,	Lift: 0.110,	Drag: 1.538
# Step: 164/279,	Lift: 0.115,	Drag: 1.538
# Step: 165/279,	Lift: 0.121,	Drag: 1.538
# Step: 166/279,	Lift: 0.127,	Drag: 1.538
# Step: 167/279,	Lift: 0.132,	Drag: 1.538
# Step: 168/279,	Lift: 0.138,	Drag: 1.539
# Step: 169/279,	Lift: 0.144,	Drag: 1.539
# Step: 170/279,	Lift: 0.150,	Drag: 1.539
# Step: 171/279,	Lift: 0.156,	Drag: 1.539
# Step: 172/279,	Lift: 0.162,	Drag: 1.539
# Step: 173/279,	Lift: 0.168,	Drag: 1.539
# Step: 174/279,	Lift: 0.173,	Drag: 1.539
# Step: 175/279,	Lift: 0.179,	Drag: 1.539
# Step: 176/279,	Lift: 0.186,	Drag: 1.539
# Step: 177/279,	Lift: 0.192,	Drag: 1.539
# Step: 178/279,	Lift: 0.198,	Drag: 1.539
# Step: 179/279,	Lift: 0.204,	Drag: 1.539
# Step: 180/279,	Lift: 0.210,	Drag: 1.540
# Step: 181/279,	Lift: 0.216,	Drag: 1.540
# Step: 182/279,	Lift: 0.222,	Drag: 1.540
# Step: 183/279,	Lift: 0.228,	Drag: 1.540
# Step: 184/279,	Lift: 0.235,	Drag: 1.540
# Step: 185/279,	Lift: 0.241,	Drag: 1.540
# Step: 186/279,	Lift: 0.247,	Drag: 1.540
# Step: 187/279,	Lift: 0.254,	Drag: 1.539
# Step: 188/279,	Lift: 0.260,	Drag: 1.539
# Step: 189/279,	Lift: 0.266,	Drag: 1.539
# Step: 190/279,	Lift: 0.273,	Drag: 1.539
# Step: 191/279,	Lift: 0.279,	Drag: 1.539
# Step: 192/279,	Lift: 0.285,	Drag: 1.539
# Step: 193/279,	Lift: 0.292,	Drag: 1.539
# Step: 194/279,	Lift: 0.298,	Drag: 1.539
# Step: 195/279,	Lift: 0.305,	Drag: 1.539
# Step: 196/279,	Lift: 0.311,	Drag: 1.539
# Step: 197/279,	Lift: 0.318,	Drag: 1.539
# Step: 198/279,	Lift: 0.324,	Drag: 1.539
# Step: 199/279,	Lift: 0.331,	Drag: 1.539
# Step: 200/279,	Lift: 0.337,	Drag: 1.539
# Step: 201/279,	Lift: 0.344,	Drag: 1.538
# Step: 202/279,	Lift: 0.351,	Drag: 1.538
# Step: 203/279,	Lift: 0.357,	Drag: 1.538
# Step: 204/279,	Lift: 0.364,	Drag: 1.538
# Step: 205/279,	Lift: 0.370,	Drag: 1.538
# Step: 206/279,	Lift: 0.377,	Drag: 1.538
# Step: 207/279,	Lift: 0.384,	Drag: 1.538
# Step: 208/279,	Lift: 0.390,	Drag: 1.537
# Step: 209/279,	Lift: 0.397,	Drag: 1.537
# Step: 210/279,	Lift: 0.404,	Drag: 1.537
# Step: 211/279,	Lift: 0.410,	Drag: 1.537
# Step: 212/279,	Lift: 0.417,	Drag: 1.537
# Step: 213/279,	Lift: 0.424,	Drag: 1.537
# Step: 214/279,	Lift: 0.430,	Drag: 1.537
# Step: 215/279,	Lift: 0.437,	Drag: 1.536
# Step: 216/279,	Lift: 0.444,	Drag: 1.536
# Step: 217/279,	Lift: 0.450,	Drag: 1.536
# Step: 218/279,	Lift: 0.457,	Drag: 1.536
# Step: 219/279,	Lift: 0.464,	Drag: 1.536
# Step: 220/279,	Lift: 0.471,	Drag: 1.536
# Step: 221/279,	Lift: 0.477,	Drag: 1.535
# Step: 222/279,	Lift: 0.484,	Drag: 1.535
# Step: 223/279,	Lift: 0.491,	Drag: 1.535
# Step: 224/279,	Lift: 0.498,	Drag: 1.535
# Step: 225/279,	Lift: 0.504,	Drag: 1.535
# Step: 226/279,	Lift: 0.511,	Drag: 1.535
# Step: 227/279,	Lift: 0.518,	Drag: 1.534
# Step: 228/279,	Lift: 0.524,	Drag: 1.534
# Step: 229/279,	Lift: 0.531,	Drag: 1.534
# Step: 230/279,	Lift: 0.538,	Drag: 1.534
# Step: 231/279,	Lift: 0.545,	Drag: 1.534
# Step: 232/279,	Lift: 0.551,	Drag: 1.534
# Step: 233/279,	Lift: 0.558,	Drag: 1.533
# Step: 234/279,	Lift: 0.565,	Drag: 1.533
# Step: 235/279,	Lift: 0.571,	Drag: 1.533
# Step: 236/279,	Lift: 0.578,	Drag: 1.533
# Step: 237/279,	Lift: 0.585,	Drag: 1.533
# Step: 238/279,	Lift: 0.591,	Drag: 1.533
# Step: 239/279,	Lift: 0.598,	Drag: 1.532
# Step: 240/279,	Lift: 0.605,	Drag: 1.532
# Step: 241/279,	Lift: 0.611,	Drag: 1.532
# Step: 242/279,	Lift: 0.618,	Drag: 1.532
# Step: 243/279,	Lift: 0.624,	Drag: 1.532
# Step: 244/279,	Lift: 0.631,	Drag: 1.532
# Step: 245/279,	Lift: 0.638,	Drag: 1.532
# Step: 246/279,	Lift: 0.644,	Drag: 1.531
# Step: 247/279,	Lift: 0.651,	Drag: 1.531
# Step: 248/279,	Lift: 0.657,	Drag: 1.531
# Step: 249/279,	Lift: 0.664,	Drag: 1.531
# Step: 250/279,	Lift: 0.670,	Drag: 1.531
# Step: 251/279,	Lift: 0.677,	Drag: 1.531
# Step: 252/279,	Lift: 0.683,	Drag: 1.531
# Step: 253/279,	Lift: 0.690,	Drag: 1.531
# Step: 254/279,	Lift: 0.696,	Drag: 1.531
# Step: 255/279,	Lift: 0.702,	Drag: 1.531
# Step: 256/279,	Lift: 0.709,	Drag: 1.530
# Step: 257/279,	Lift: 0.715,	Drag: 1.530
# Step: 258/279,	Lift: 0.721,	Drag: 1.530
# Step: 259/279,	Lift: 0.728,	Drag: 1.530
# Step: 260/279,	Lift: 0.734,	Drag: 1.530
# Step: 261/279,	Lift: 0.740,	Drag: 1.530
# Step: 262/279,	Lift: 0.746,	Drag: 1.530
# Step: 263/279,	Lift: 0.753,	Drag: 1.530
# Step: 264/279,	Lift: 0.759,	Drag: 1.530
# Step: 265/279,	Lift: 0.765,	Drag: 1.530
# Step: 266/279,	Lift: 0.771,	Drag: 1.530
# Step: 267/279,	Lift: 0.777,	Drag: 1.530
# Step: 268/279,	Lift: 0.783,	Drag: 1.530
# Step: 269/279,	Lift: 0.789,	Drag: 1.530
# Step: 270/279,	Lift: 0.795,	Drag: 1.530
# Step: 271/279,	Lift: 0.801,	Drag: 1.530
# Step: 272/279,	Lift: 0.807,	Drag: 1.530
# Step: 273/279,	Lift: 0.813,	Drag: 1.530
# Step: 274/279,	Lift: 0.819,	Drag: 1.530
# Step: 275/279,	Lift: 0.825,	Drag: 1.530
# Step: 276/279,	Lift: 0.830,	Drag: 1.530
# Step: 277/279,	Lift: 0.836,	Drag: 1.530
# Step: 278/279,	Lift: 0.842,	Drag: 1.530
# Step: 279/279,	Lift: 0.847,	Drag: 1.530

# %%
fig, ax = plt.subplots(1, 1, figsize=(7.5, 3))
env.render(axes=ax, cmap=sns.color_palette("icefire", as_cmap=True))
ax.set_xlim([-2, 9])
ax.set_ylim([-2, 2])
# Out:
# (-2.0, 2.0)

# %% [markdown]
# ### Low-fidelity "training meshes"
#
# Since it's relatively expensive to simulate these flows on fully-resolved meshes, some of the flows also have coarse "training meshes" that can be used for training deep RL controllers, for instance.
#
# As a benchmark test, let's solve for the unstable steady state with the "medium" and "coarse" meshes (see the next section for more details)

# %%
env_config = {
    "flow": hgym.RotaryCylinder,
    "flow_config": {
        "Re" :100,
        "restart": f"{precomputed_data}/checkpoint.h5",
        "mesh":'medium',
        "velocity_order":1
    },
    "solver_config":{
        "dt":0.01,
    },
    "solver": hgym.SemiImplicitBDF,
}
env = hgym.FlowEnv(env_config)

print(env.flow.mixed_space.dim())  # Number of degrees of freedom
# Out:
# 26232

# %%
solver = hgym.NewtonSolver(env.flow,stabilization='none')
solver.solve()
env.flow.get_observations()  # Lift, drag

# %%
fig, ax = plt.subplots(1, 1, figsize=(7.5, 3))
env.render(axes=ax, cmap=sns.color_palette("icefire", as_cmap=True))
ax.set_xlim([-2, 9])
ax.set_ylim([-2, 2])
# Out:
# (-2.0, 2.0)

# %%
env_config["flow_config"]["mesh"] = "coarse"
env = hgym.FlowEnv(env_config)

print(env.flow.mixed_space.dim())  # Number of degrees of freedom
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[34], line 2
#       1 env_config["flow_config"]["mesh"] = "coarse"
# ----> 2 env = hgym.FlowEnv(env_config)
#       4 print(env.flow.mixed_space.dim())  # Number of degrees of freedom
#
# File ~/miniconda3/envs/hydrogym/lib/python3.12/site-packages/hydrogym/core.py:326, in FlowEnv.__init__(self, env_config)
#     325 def __init__(self, env_config: dict):
# --> 326   self.flow: PDEBase = env_config.get("flow")(
#     327       **env_config.get("flow_config", {}))
#     328   self.solver: TransientSolver = env_config.get("solver")(
#     329       self.flow, **env_config.get("solver_config", {}))
#     330   self.callbacks: Iterable[CallbackBase] = env_config.get("callbacks", [])
#
# File ~/miniconda3/envs/hydrogym/lib/python3.12/site-packages/hydrogym/firedrake/flow.py:75, in FlowConfig.__init__(self, velocity_order, **config)
#      57 probe_obs_types = {
#      58     "velocity_probes":
#      59         ObservationFunction(
#    (...)     67             partial(self.vorticity_probe, probes), num_outputs=len(probes)),
#      68 }
#      70 self.obs_fun = self.configure_observations(
#      71     obs_type=config.pop("observation_type", None),
#      72     probe_obs_types=probe_obs_types,
#      73 )
# ---> 75 super().__init__(**config)
#
# File ~/miniconda3/envs/hydrogym/lib/python3.12/site-packages/hydrogym/core.py:49, in PDEBase.__init__(self, **config)
#      48 def __init__(self, **config):
# ---> 49   self.mesh = self.load_mesh(name=config.get("mesh", self.DEFAULT_MESH))
#      50   self.initialize_state()
#      52   self.reset()
#
# File ~/miniconda3/envs/hydrogym/lib/python3.12/site-packages/hydrogym/firedrake/flow.py:78, in FlowConfig.load_mesh(self, name)
#      77 def load_mesh(self, name: str) -> ufl.Mesh:
# ---> 78   return fd.Mesh(f"{self.MESH_DIR}/{name}.msh", name="mesh")
#
# File petsc4py/PETSc/Log.pyx:188, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File petsc4py/PETSc/Log.pyx:189, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File ~/miniconda3/envs/hydrogym/lib/python3.12/site-packages/firedrake/mesh.py:3090, in Mesh(meshfile, **kwargs)
#    3088     opts = OptionsManager(opts, "")
#    3089     with opts.inserted_options():
# -> 3090         plex = _from_gmsh(meshfile, user_comm)
#    3091 elif ext.lower() == '.node':
#    3092     plex = _from_triangle(meshfile, geometric_dim, user_comm)
#
# File petsc4py/PETSc/Log.pyx:188, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File petsc4py/PETSc/Log.pyx:189, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File ~/miniconda3/envs/hydrogym/lib/python3.12/site-packages/firedrake/mesh.py:369, in _from_gmsh(filename, comm)
#     363 """Read a Gmsh .msh file from `filename`.
#     364
#     365 :kwarg comm: Optional communicator to build the mesh on (defaults to
#     366     COMM_WORLD).
#     367 """
#     368 comm = comm or COMM_WORLD
# --> 369 gmsh_plex = PETSc.DMPlex().createFromFile(filename, comm=comm)
#     371 return gmsh_plex
#
# File petsc4py/PETSc/DMPlex.pyx:222, in petsc4py.PETSc.DMPlex.createFromFile()
#
# Error: error code 65
# [0] DMPlexCreateFromFile() at /home/jay/firedrake/petsc/src/dm/impls/plex/plexcreate.c:6249
# [0] DMPlexCreateGmshFromFile() at /home/jay/firedrake/petsc/src/dm/impls/plex/plexgmsh.c:1511
# [0] PetscViewerFileSetName() at /home/jay/firedrake/petsc/src/sys/classes/viewer/impls/ascii/filev.c:764
# [0] PetscViewerFileSetName_ASCII() at /home/jay/firedrake/petsc/src/sys/classes/viewer/impls/ascii/filev.c:868
# [0] Unable to open file
# [0] Cannot open PetscViewer file: /home/jay/miniconda3/envs/hydrogym/lib/python3.12/site-packages/hydrogym/firedrake/envs/cylinder/coarse.msh due to "No such file or directory"

# %%
# %%time

solver = hgym.NewtonSolver(env.flow)
solver.solve()

env.flow.get_observations()  # Lift, drag
# Out:
# CPU times: user 762 ms, sys: 60 ms, total: 822 ms
# Wall time: 819 ms
# (0.0028255549720681587, 1.2654845077905303)

# %%
fig, ax = plt.subplots(1, 1, figsize=(7.5, 3))
env.render(axes=ax, cmap=sns.color_palette("icefire", as_cmap=True))
ax.set_xlim([-2, 9])
ax.set_ylim([-2, 2])
# Out:
# (-2.0, 2.0)

# %% [markdown]
# The resolution is noticeably worse, but you get about a 10x speedup.  Note that the performance of a controller should *not* be reported based on coarse simulation.  For the cylinder there is also a "fine" mesh based on [Sipp & Lebedev (2007)](https://www.cambridge.org/core/journals/journal-of-fluid-mechanics/article/global-stability-of-base-and-mean-flows-a-general-approach-and-its-applications-to-cylinder-and-open-cavity-flows/EC31631718EB33AA5C671A8F7EAA043C) that extends much farther, which is useful in doing model-based control that requires adjoint modes, for instance.  This one has about 10x as many degrees of freedom as the "medium" model, however, so time-varying simulation on this domain is very expensive.

# %%
env_config["flow_config"]["mesh"] = "fine"
env = hgym.FlowEnv(env_config)

print(env.flow.mixed_space.dim())  # Number of degrees of freedom

fig, ax = plt.subplots(1, 1, figsize=(12, 2))
env.render(axes=ax)

# %% [markdown]
# # Under the hood

# %% [markdown]
# The `FlowEnv` is actually just a wrapper around two other objects that give finer-grained control: the `FlowConfig` and `TransientSolver` classes.
#
# The default solver is called an "Incremental Pressure Correction Scheme" (IPCS), although support for other timestepping methods is planned.

# %%
env.flow, env.solver
# Out:
# (<hydrogym.firedrake.envs.cylinder.flow.Cylinder at 0x7f67d7b28400>,
#  <hydrogym.firedrake.solver.IPCS at 0x7f67d7adabc0>)

# %% [markdown]
# The solver can be advanced on its own in almost the exact same way as the `FlowEnv`, except you have to input controls and read out observations manually.  So these two are exactly equivalent:

# %%
env_config = {
    "flow": hgym.Cylinder,
    "flow_config": {
        "mesh": "medium",  # Default mesh
    },
    "solver": hgym.IPCS,
}
env = hgym.FlowEnv(env_config)

# %%
num_steps = 5

print("Advancing with `FlowEnv`")
env.reset()
for i in range(num_steps):
    (CL, CD), _, _, _ = env.step()
    print(f"\tStep: {i+1}/{num_steps},\tLift: {CL:0.3f},\tDrag: {CD:0.3f}")


print("Advancing with `env.solver`")
env.reset()
for i in range(num_steps):
    env.solver.step(i)
    (CL, CD) = env.flow.get_observations()
    print(f"\tStep: {i+1}/{num_steps},\tLift: {CL:0.3f},\tDrag: {CD:0.3f}")
# Out:
# Advancing with `FlowEnv`
# 	Step: 1/5,	Lift: 0.346,	Drag: 1.507
# 	Step: 2/5,	Lift: 0.344,	Drag: 1.507
# 	Step: 3/5,	Lift: 0.342,	Drag: 1.507
# 	Step: 4/5,	Lift: 0.341,	Drag: 1.507
# 	Step: 5/5,	Lift: 0.339,	Drag: 1.507
# Advancing with `env.solver`
# 	Step: 1/5,	Lift: 0.346,	Drag: 1.507
# 	Step: 2/5,	Lift: 0.344,	Drag: 1.507
# 	Step: 3/5,	Lift: 0.342,	Drag: 1.507
# 	Step: 4/5,	Lift: 0.341,	Drag: 1.507
# 	Step: 5/5,	Lift: 0.339,	Drag: 1.507

# %% [markdown]
# Working at this level the `FlowEnv` can be ignored altogether.  In this case there is an `integrate` method in the `ts` module that will advance the flow.

# %%
dt = env.solver.dt  # To be consistent with the previous cell
flow = hgym.Cylinder(
    restart=f"{precomputed_data}/checkpoint.h5"
)  # Same initial state as the `FlowEnv`
flow = hgym.integrate(flow, t_span=(0, num_steps * dt), dt=dt)
# Compute lift/drag, just as with env.collect_observations()
(CL, CD) = flow.compute_forces()
print(f"Lift: {CL:0.3f},\tDrag: {CD:0.3f}")
# Out:
# Lift: 0.339,	Drag: 1.507

# %% [markdown]
# The `FlowConfig` also gives you much more access.  For instance, we can use a Newton solver to find the unstable symmetric state of the flow.  This also accepts parameters to the underlying PETSc SNES solver

# %%
# Runtime: 10s
cyl = hgym.Cylinder()

solver = hgym.NewtonSolver(cyl, solver_parameters={"snes_monitor": None})
qB = solver.solve()  # Base flow: [u, p]
# Out:
#   0 SNES Function norm 2.159126957610e+00
#   1 SNES Function norm 1.299251918642e+00
#   2 SNES Function norm 3.310997003024e-01
#   3 SNES Function norm 2.176239845147e-02
#   4 SNES Function norm 8.767680600725e-03
#   5 SNES Function norm 1.335957275478e-03
#   6 SNES Function norm 1.094354459850e-04
#   7 SNES Function norm 1.957098965798e-07
#   8 SNES Function norm 1.363811547080e-12

# %%
# Now we can't use `env.render()`, but it's easy to do something similar with firedrake
fig, ax = plt.subplots(1, 1, figsize=(7.5, 3))
levels = np.linspace(-3, 3, 10)
fd.tricontourf(
    cyl.vorticity(),
    levels=levels,
    axes=ax,
    cmap=sns.color_palette("icefire", as_cmap=True),
)
ax.set_xlim([-2, 9])
ax.set_ylim([-2, 2])
plt.show()

# %% [markdown]
# ### I/O and callbacks

# %% [markdown]
# HydroGym implements a lot of input/output via "callbacks".  These are callable classes that will check the iteration count of the simulation and do something if it matches up with their internal clock.  Effectively this acts like a function like
# ```
# def cb(iter, t, flow):
#     # Do something with the flow
# ```
# but it only gets called every `interval` steps, as defined when the object is initialized.

# %% [raw]
# help(gym.core.CallbackBase)

# %% [markdown]
# Simple callbacks can save a checkpoint or visualization file every so often, or write some custom output to a file.  You can also set up controllers with the callbacks, as we'll see in a minute.
#
# You can set up a list of callbacks and pass them to either `ts.integrate` or `env.step`. For instance, suppose we want to write out a checkpoint every 5 steps.  The setup for this is just

# %% [raw]
# output_dir = "./demo_output"
# chk = gym.io.CheckpointCallback(interval=5, filename=f"{output_dir}/checkpoint.h5")

# %% [raw]
# !mkdir $output_dir
# !ls $output_dir

# %% [markdown]
# As a slightly more complicated example, we can set up a callback to print some output to the terminal.  You can use a `LogCallback` for this:

# %% [raw]
# # This is the function that will get called every time.
# #   It should return a tuple or array of whatever you want logged
# def log_postprocess(flow):
#     return flow.collect_observations()
#
#
# # Set up the callback
# print_fmt = "t: {0},\t\t CL:{1:0.3f},\t\t CD:{2:0.03f}"  # This will format the output
# log = gym.io.LogCallback(
#     postprocess=log_postprocess, nvals=2, interval=1, print_fmt=print_fmt
# )

# %% [markdown]
# We could also have set the log to save to a file by including a `filename` keyword argument.
#
# Another common case is visualization in Paraview. The default behavior here is to write out the velocity and pressure, but it can also be modified with another `postprocess` function.  For instance, to also save vorticity every 5 steps:

# %% [raw]
# def pvd_postprocess(flow):
#     vort = flow.vorticity()
#     return (flow.u, flow.p, vort)
#
#
# pvd = gym.io.ParaviewCallback(
#     postprocess=pvd_postprocess, interval=5, filename=f"{output_dir}/solution.pvd"
# )

# %% [raw]
# callbacks = [log, chk, pvd]
#
# dt = 1e-2
# num_steps = 10
# flow = gym.flow.Cylinder(
#     h5_file=f"{precomputed_data}/checkpoint.h5"
# )  # Same initial state as the `FlowEnv`
# flow = gym.ts.integrate(flow, t_span=(0, num_steps * dt), dt=dt, callbacks=callbacks)
# (
#     CL,
#     CD,
# ) = flow.compute_forces()  # Compute lift/drag, just as with env.collect_observations()

# %% [markdown]
# Now we should see the files appearing in the output directory

# %% [raw]
# !ls $output_dir

# %% [markdown]
# The log output is still in the callback object, if we wanted it for anything.

# %% [raw]
# log.data

# %% [raw]
# !rm -r $output_dir

# %% [markdown]
# ### Differentiating through the solver
#
# The solver is (or can be configured to be) differentiable with respect to many parameters by means of the [pyadjoint library](https://pyadjoint.readthedocs.io/en/release/documentation/pyadjoint_docs.html).  This is really set up for large-scale PDE-constrained optimization, but as a simple example we can take the derivative with respect to a proportional gain over a few timesteps (but note that this specific approach is *not* a good way to optimize gains... you effectively multiply the gain by itself many times and get numerical issues similar to what would happen if you naively tried to train a RNN).
#
# Also note the `differentiable` flag on the environment initialization.  This selects a different timestepper `hydrogym.ts.IPCS_diff` that is slightly less efficient but allows for differentiating with respect to the boundary conditions, which is how the rotation control is implemented here.

# %%
env_config = {
    "flow": hgym.Cylinder,
    "flow_config": {
        "restart": f"{precomputed_data}/checkpoint.h5",
    },
    "solver": hgym.IPCS_diff,
}
env = hgym.FlowEnv(env_config)

y = env.reset()


# Simple opposition control on lift
def feedback_ctrl(y, K=0.1):
    CL, CD = y
    return K * CL


J = fda.AdjFloat(0.0)
num_steps = 10
K = fda.AdjFloat(0.1)
# K = fd.Constant(0.1)
for _ in range(num_steps):
    y, reward, done, info = env.step(feedback_ctrl(y, K=K))
    J = J - reward


dK = fda.compute_gradient(J, fda.Control(K))
dK
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [5], line 28
#      24     y, reward, done, info = env.step(feedback_ctrl(y, K=K))
#      25     J = J - reward
# ---> 28 dK = fda.compute_gradient(J, fda.Control(K))
#      29 dK
#
# File ~/firedrake/src/pyadjoint/pyadjoint/drivers.py:29, in compute_gradient(J, m, options, tape, adj_value)
#      27 with stop_annotating():
#      28     with tape.marked_nodes(m):
# ---> 29         tape.evaluate_adj(markings=True)
#      31 grads = [i.get_derivative(options=options) for i in m]
#      32 return m.delist(grads)
#
# File ~/firedrake/src/pyadjoint/pyadjoint/tape.py:192, in Tape.evaluate_adj(self, last_block, markings)
#     188 def evaluate_adj(self, last_block=0, markings=False):
#     189     for i in self._bar("Evaluating adjoint").iter(
#     190         range(len(self._blocks) - 1, last_block - 1, -1)
#     191     ):
# --> 192         self._blocks[i].evaluate_adj(markings=markings)
#
# File ~/firedrake/src/pyadjoint/pyadjoint/tape.py:69, in no_annotations.<locals>.wrapper(*args, **kwargs)
#      66 @wraps(function)
#      67 def wrapper(*args, **kwargs):
#      68     with stop_annotating():
# ---> 69         return function(*args, **kwargs)
#
# File ~/firedrake/src/pyadjoint/pyadjoint/block.py:131, in Block.evaluate_adj(self, markings)
#     128 prepared = self.prepare_evaluate_adj(inputs, adj_inputs, relevant_dependencies)
#     130 for idx, dep in relevant_dependencies:
# --> 131     adj_output = self.evaluate_adj_component(inputs,
#     132                                              adj_inputs,
#     133                                              dep,
#     134                                              idx,
#     135                                              prepared)
#     136     if adj_output is not None:
#     137         dep.add_adj_output(adj_output)
#
# File ~/firedrake/src/pyadjoint/dolfin_adjoint_common/blocks/constant.py:53, in ConstantAssignBlock.evaluate_adj_component(self, inputs, adj_inputs, block_variable, idx, prepared)
#      50 if self.assigned_float:
#      51     # Convert to float
#      52     adj_output = gather(adj_output)
# ---> 53     adj_output = float(adj_output[0])
#      54 elif self.assigned_list:
#      55     adj_output = prepared[self.dependency_to_index[idx]]
#
# IndexError: invalid index to scalar variable.

# %% [markdown]
# As another example that's more in line with the reverse-mode AD purpose of pyadjoint, we could compute the sensitivity of the final solution with respect to an initial condition.  We could just use the `FlowEnv`, but this shows you can do the same thing with the timestepping functionality. Again, note that the differentiable form of the IPCS solver is specified here.

# %%
dt = 1e-2
num_steps = 10

cyl = hgym.Cylinder(restart=f"{precomputed_data}/checkpoint.h5")

# Store a copy of the initial condition to distinguish it from the time-varying solution
q0 = cyl.q.copy(deepcopy=True)
cyl.q.assign(
    q0, annotate=True
)  # Note the annotation flag so that the assignment is tracked

# Time step forward as usual
cyl = hgym.integrate(cyl, t_span=(0, num_steps * dt), dt=dt, method="IPCS_diff")

# Define a cost functional... here we're just using the energy inner product
J = 0.5 * fd.assemble(inner(cyl.u, cyl.u) * dx)

# Compute the gradient with respect to the initial condition
#   The option for Riesz representation here specifies that we should end up back in the primal space
dq = fda.compute_gradient(J, fda.Control(q0), options={"riesz_representation": "L2"})

# %%
# Split out velocity and pressure components from the fields
u0, p0 = q0.split()
du, dp = dq.split()

fig, ax = plt.subplots(1, 1, figsize=(7.5, 3))
im = fd.tripcolor(u0, axes=ax, cmap=sns.color_palette("icefire", as_cmap=True))
ax.set_xlim([-2, 9])
ax.set_ylim([-2, 2])
plt.title("Initial velocity magnitude")
plt.show()

fig, ax = plt.subplots(1, 1, figsize=(7.5, 3))
im = fd.tripcolor(du, axes=ax, cmap=sns.color_palette("icefire", as_cmap=True))
plt.title("Sensitivity magnitude")
ax.set_xlim([-2, 9])
ax.set_ylim([-2, 2])
plt.show()

# %% [markdown]
# # Low-level interface
#
# The efficiency and parallelization in Firedrake (and by extension, HydroGym) is largely due to the fact that the heavy-duty linear algebra is handled behind the scenes by [PETSc](https://petsc.org/release/).  This gives us access to the full range of powerful linear algebra tools in PETSc if we work with the underlying PETSc data structures representing vectors and sparse matrices.  See also the [Firedrake docs](https://www.firedrakeproject.org/petsc-interface.html) for more detail.
#
# This isn't always totally straightforward; for instance, by default PETSc is compiled with real-valued scalar types, so in order to do global stability analysis you have to run in complex mode.  The HydroGym docker image comes with a second virtual environment where this is all configured, so you just have to activate the `firedrake-complex` environment rather than `firedrake`. This does create some headaches passing data back and forth, but it's worth it for the parallelization.  See the stability analysis examples for more detail there.
#
# In some cases it may even be necessary to extract the underlying matrix and vectors themselves.  For instance, when using the Modred interface for modal analysis, it's actually better to convert the data to numpy arrays rather than working with the `PETSc.Vec` or `fd.Function` objects because of the differences in how Modred and Firerake/PETSc handle parallelization.  For instance, if we want to extract a linear operator as a sparse CSR matrix, we can do something like this:
